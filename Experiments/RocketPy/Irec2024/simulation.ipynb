# %% [markdown]
# # RocketPy Simulation
# This notebook was generated using Rocket-Serializer, a RocketPy tool to convert simulation files to RocketPy simulations
# The notebook was generated using the following parameters file: `Irec2024/parameters.json`

# %%
# %pip install rocketpy<=2.0
# Out:
# /bin/bash: line 1: =2.0: No such file or directory
# Note: you may need to restart the kernel to use updated packages.

# %%
from rocketpy import Environment, SolidMotor, Rocket, Flight, TrapezoidalFins, EllipticalFins, RailButtons, NoseCone, Tail, Parachute
import datetime

# %% [markdown]
# ## Environment

# %%
env = Environment()
env.set_location(latitude=33.0, longitude=-107.0)
env.set_elevation(1522.476)
# Out:
# /home/unknown/Clubs/Launch/Misc/DeploymentMod/.direnv/python-3.12/lib/python3.12/site-packages/rocketpy/mathutils/function.py:3125: UserWarning: Extrapolation method set to 'constant' because the linear method is not supported.
#   warnings.warn(

# %% [markdown]
# Optionally, you can set the date and atmospheric model

# %%
tomorrow = datetime.date.today() + datetime.timedelta(days=1)
env.set_date((tomorrow.year, tomorrow.month, tomorrow.day, 12))
# env.set_atmospheric_model(type='Forecast', file='GFS')

# %%
env.all_info()
# Out:
# Gravity Details
#
# Acceleration of gravity at surface level:    9.7756 m/s²
# Acceleration of gravity at  80.000 km (ASL): 9.5379 m/s²
#
#
# Launch Site Details
#
# Launch Date: 2024-08-15 12:00:00 UTC
# Launch Site Latitude: 33.00000°
# Launch Site Longitude: -107.00000°
# Reference Datum: SIRGAS2000
# Launch Site UTM coordinates: 166021.44 W|E    0.00 N
# Launch Site UTM zone: 31N
# Launch Site Surface Elevation: 1522.5 m
#
#
# Atmospheric Model Details
#
# Atmospheric Model Type: standard_atmosphere
# standard_atmosphere Maximum Height: 80.000 km
#
# Surface Atmospheric Conditions
#
# Surface Wind Speed: 0.00 m/s
# Surface Wind Direction: 0.00°
# Surface Wind Heading: 0.00°
# Surface Pressure: 843.25 hPa
# Surface Temperature: 278.27 K
# Surface Air Density: 1.056 kg/m³
# Surface Speed of Sound: 334.05 m/s
#
#
# Earth Model Details
#
# Earth Radius at Launch site: 6378.14 km
# Semi-major Axis: 6378.14 km
# Semi-minor Axis: 6356.75 km
# Flattening: 0.0034
#
#
#
# Gravity Model Plots
# Atmospheric Model Plots

# %% [markdown]
# ## Motor
# Currently, only Solid Motors are supported by Rocket-Serializer. If you want to use a Liquid/Hybrid motor, please use rocketpy directly.

# %%
motor = SolidMotor(
    thrust_source='thrust_source.csv',
    dry_mass=0,
    center_of_dry_mass_position=0,
    dry_inertia=[0, 0, 0],
    grains_center_of_mass_position=0,
    grain_number=1,
    grain_density=1197.8232626056745,
    grain_outer_radius=0.049,
    grain_initial_inner_radius=0.0245,
    grain_initial_height=0.702,
    grain_separation=0,
    nozzle_radius=0.036750000000000005,
    nozzle_position=-0.351,
    throat_radius=0.0245,
    reshape_thrust_curve=False,  # Not implemented in Rocket-Serializer
    interpolation_method='linear',
    coordinate_system_orientation='nozzle_to_combustion_chamber',
)
# Out:
# /home/unknown/Clubs/Launch/Misc/DeploymentMod/.direnv/python-3.12/lib/python3.12/site-packages/rocketpy/mathutils/function.py:1595: RuntimeWarning: invalid value encountered in divide
#   vector_b.extend(3 * ((y[2:] - y[1:-1]) / h[1:] - (y[1:-1] - y[:-2]) / h[:-1]))
# capi_return is NULL
# Call-back cb_f_in_lsoda__user__routines failed.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/Clubs/Launch/Misc/DeploymentMod/.direnv/python-3.12/lib/python3.12/site-packages/rocketpy/motors/solid_motor.py:414, in SolidMotor.mass_flow_rate(self)
#     413 try:
# --> 414     return self._mass_flow_rate
#     415 except AttributeError:
#
# AttributeError: 'SolidMotor' object has no attribute '_mass_flow_rate'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/Clubs/Launch/Misc/DeploymentMod/.direnv/python-3.12/lib/python3.12/site-packages/rocketpy/mathutils/function.py:3341, in funcify_method.<locals>.funcify_method_decorator.__get__(self, instance, owner)
#    3339 try:
#    3340     # If cache is ready, return it
# -> 3341     val = cache[self.attrname]
#    3342 except KeyError:
#    3343     # If cache is not ready, create it
#
# KeyError: 'total_mass_flow_rate'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/Clubs/Launch/Misc/DeploymentMod/.direnv/python-3.12/lib/python3.12/site-packages/rocketpy/mathutils/function.py:3341, in funcify_method.<locals>.funcify_method_decorator.__get__(self, instance, owner)
#    3339 try:
#    3340     # If cache is ready, return it
# -> 3341     val = cache[self.attrname]
#    3342 except KeyError:
#    3343     # If cache is not ready, create it
#
# KeyError: 'exhaust_velocity'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 motor = SolidMotor(
#       2     thrust_source='thrust_source.csv',
#       3     dry_mass=0,
#       4     center_of_dry_mass_position=0,
#       5     dry_inertia=[0, 0, 0],
#       6     grains_center_of_mass_position=0,
#       7     grain_number=1,
#       8     grain_density=1197.8232626056745,
#       9     grain_outer_radius=0.049,
#      10     grain_initial_inner_radius=0.0245,
#      11     grain_initial_height=0.702,
#      12     grain_separation=0,
#      13     nozzle_radius=0.036750000000000005,
#      14     nozzle_position=-0.351,
#      15     throat_radius=0.0245,
#      16     reshape_thrust_curve=False,  # Not implemented in Rocket-Serializer
#      17     interpolation_method='linear',
#      18     coordinate_system_orientation='nozzle_to_combustion_chamber',
#      19 )
#
# File ~/Clubs/Launch/Misc/DeploymentMod/.direnv/python-3.12/lib/python3.12/site-packages/rocketpy/motors/solid_motor.py:338, in SolidMotor.__init__(self, thrust_source, dry_mass, dry_inertia, nozzle_radius, grain_number, grain_density, grain_outer_radius, grain_initial_inner_radius, grain_initial_height, grain_separation, grains_center_of_mass_position, center_of_dry_mass_position, nozzle_position, burn_time, throat_radius, reshape_thrust_curve, interpolation_method, coordinate_system_orientation)
#     331 self.grain_initial_volume = (
#     332     self.grain_initial_height
#     333     * np.pi
#     334     * (self.grain_outer_radius**2 - self.grain_initial_inner_radius**2)
#     335 )
#     336 self.grain_initial_mass = self.grain_density * self.grain_initial_volume
# --> 338 self.evaluate_geometry()
#     340 # Initialize plots and prints object
#     341 self.prints = _SolidMotorPrints(self)
#
# File ~/Clubs/Launch/Misc/DeploymentMod/.direnv/python-3.12/lib/python3.12/site-packages/rocketpy/motors/solid_motor.py:536, in SolidMotor.evaluate_geometry(self)
#     533 terminate_burn.direction = -1
#     535 # Solve the system of differential equations
# --> 536 sol = integrate.solve_ivp(
#     537     geometry_dot,
#     538     t_span,
#     539     y0,
#     540     jac=geometry_jacobian,
#     541     events=terminate_burn,
#     542     atol=1e-12,
#     543     rtol=1e-11,
#     544     method="LSODA",
#     545 )
#     547 self.grain_burn_out = sol.t[-1]
#     549 # Write down functions for innerRadius and height
#
# File ~/Clubs/Launch/Misc/DeploymentMod/.direnv/python-3.12/lib/python3.12/site-packages/scipy/integrate/_ivp/ivp.py:655, in solve_ivp(fun, t_span, y0, method, t_eval, dense_output, events, vectorized, args, **options)
#     653 status = None
#     654 while status is None:
# --> 655     message = solver.step()
#     657     if solver.status == 'finished':
#     658         status = 0
#
# File ~/Clubs/Launch/Misc/DeploymentMod/.direnv/python-3.12/lib/python3.12/site-packages/scipy/integrate/_ivp/base.py:197, in OdeSolver.step(self)
#     195 else:
#     196     t = self.t
# --> 197     success, message = self._step_impl()
#     199     if not success:
#     200         self.status = 'failed'
#
# File ~/Clubs/Launch/Misc/DeploymentMod/.direnv/python-3.12/lib/python3.12/site-packages/scipy/integrate/_ivp/lsoda.py:161, in LSODA._step_impl(self)
#     159 itask = integrator.call_args[2]
#     160 integrator.call_args[2] = 5
# --> 161 solver._y, solver.t = integrator.run(
#     162     solver.f, solver.jac or (lambda: None), solver._y, solver.t,
#     163     self.t_bound, solver.f_params, solver.jac_params)
#     164 integrator.call_args[2] = itask
#     166 if solver.successful():
#
# File ~/Clubs/Launch/Misc/DeploymentMod/.direnv/python-3.12/lib/python3.12/site-packages/scipy/integrate/_ode.py:1347, in lsoda.run(self, f, jac, y0, t0, t1, f_params, jac_params)
#    1344     self.acquire_new_handle()
#    1345 args = [f, y0, t0, t1] + self.call_args[:-1] + \
#    1346        [jac, self.call_args[-1], f_params, 0, jac_params]
# -> 1347 y1, t, istate = self.runner(*args)
#    1348 self.istate = istate
#    1349 if istate < 0:
#
# File ~/Clubs/Launch/Misc/DeploymentMod/.direnv/python-3.12/lib/python3.12/site-packages/scipy/integrate/_ivp/base.py:154, in OdeSolver.__init__.<locals>.fun(t, y)
#     152 def fun(t, y):
#     153     self.nfev += 1
# --> 154     return self.fun_single(t, y)
#
# File ~/Clubs/Launch/Misc/DeploymentMod/.direnv/python-3.12/lib/python3.12/site-packages/scipy/integrate/_ivp/base.py:23, in check_arguments.<locals>.fun_wrapped(t, y)
#      22 def fun_wrapped(t, y):
# ---> 23     return np.asarray(fun(t, y), dtype=dtype)
#
# File ~/Clubs/Launch/Misc/DeploymentMod/.direnv/python-3.12/lib/python3.12/site-packages/rocketpy/motors/solid_motor.py:476, in SolidMotor.evaluate_geometry.<locals>.geometry_dot(t, y)
#     474 def geometry_dot(t, y):
#     475     # Store physical parameters
# --> 476     volume_diff = self.mass_flow_rate(t) / (n_grain * density)
#     478     # Compute state vector derivative
#     479     grain_inner_radius, grain_height = y
#
# File ~/Clubs/Launch/Misc/DeploymentMod/.direnv/python-3.12/lib/python3.12/site-packages/rocketpy/motors/solid_motor.py:416, in SolidMotor.mass_flow_rate(self)
#     414     return self._mass_flow_rate
#     415 except AttributeError:
# --> 416     self._mass_flow_rate = self.total_mass_flow_rate
#     417     return self._mass_flow_rate
#
# File ~/Clubs/Launch/Misc/DeploymentMod/.direnv/python-3.12/lib/python3.12/site-packages/rocketpy/mathutils/function.py:3346, in funcify_method.<locals>.funcify_method_decorator.__get__(self, instance, owner)
#    3342 except KeyError:
#    3343     # If cache is not ready, create it
#    3344     try:
#    3345         # Handle methods which return Function instances
# -> 3346         val = self.func(instance).reset(*args, **kwargs)
#    3347     except AttributeError:
#    3348         # Handle methods which return a valid source
#    3349         source = self.func(instance)
#
# File ~/Clubs/Launch/Misc/DeploymentMod/.direnv/python-3.12/lib/python3.12/site-packages/rocketpy/motors/motor.py:449, in Motor.total_mass_flow_rate(self)
#     409 @funcify_method("Time (s)", "Mass flow rate (kg/s)", extrapolation="zero")
#     410 def total_mass_flow_rate(self):
#     411     """Time derivative of the propellant mass as a function of time. The
#     412     formula used is the opposite of thrust divided by exhaust velocity.
#     413
#    (...)
#     447     grains mass flow rate will be negative, losing physical meaning.
#     448     """
# --> 449     return -1 * self.thrust / self.exhaust_velocity
#
# File ~/Clubs/Launch/Misc/DeploymentMod/.direnv/python-3.12/lib/python3.12/site-packages/rocketpy/mathutils/function.py:3346, in funcify_method.<locals>.funcify_method_decorator.__get__(self, instance, owner)
#    3342 except KeyError:
#    3343     # If cache is not ready, create it
#    3344     try:
#    3345         # Handle methods which return Function instances
# -> 3346         val = self.func(instance).reset(*args, **kwargs)
#    3347     except AttributeError:
#    3348         # Handle methods which return a valid source
#    3349         source = self.func(instance)
#
# File ~/Clubs/Launch/Misc/DeploymentMod/.direnv/python-3.12/lib/python3.12/site-packages/rocketpy/motors/solid_motor.py:383, in SolidMotor.exhaust_velocity(self)
#     371 @funcify_method("Time (s)", "Exhaust velocity (m/s)")
#     372 def exhaust_velocity(self):
#     373     """Exhaust velocity by assuming it as a constant. The formula used is
#     374     total impulse/propellant initial mass.
#     375
#    (...)
#     379         Gas exhaust velocity of the motor.
#     380     """
#     381     return Function(
#     382         self.total_impulse / self.propellant_initial_mass
# --> 383     ).set_discrete_based_on_model(self.thrust)
#
# File ~/Clubs/Launch/Misc/DeploymentMod/.direnv/python-3.12/lib/python3.12/site-packages/rocketpy/mathutils/function.py:696, in Function.set_discrete_based_on_model(self, model_function, one_by_one, keep_self, mutate_self)
#     694     xs = model_function.source[:, 0]
#     695     ys = func.get_value(xs.tolist()) if one_by_one else func.get_value(xs)
# --> 696     func.set_source(np.concatenate(([xs], [ys])).transpose())
#     697 elif func.__dom_dim__ == 2:
#     698     # Create nodes to evaluate function
#     699     xs = model_function.source[:, 0]
#
# File ~/Clubs/Launch/Misc/DeploymentMod/.direnv/python-3.12/lib/python3.12/site-packages/rocketpy/mathutils/function.py:255, in Function.set_source(self, source)
#     252         self.get_value_opt = self.__get_value_opt_nd
#     254 self.source = source
# --> 255 self.set_interpolation(self.__interpolation__)
#     256 self.set_extrapolation(self.__extrapolation__)
#     257 return self
#
# File ~/Clubs/Launch/Misc/DeploymentMod/.direnv/python-3.12/lib/python3.12/site-packages/rocketpy/mathutils/function.py:298, in Function.set_interpolation(self, method)
#     296 if not callable(self.source):
#     297     self.__interpolation__ = self.__validate_interpolation(method)
# --> 298     self.__update_interpolation_coefficients(self.__interpolation__)
#     299     self.__set_interpolation_func()
#     300 return self
#
# File ~/Clubs/Launch/Misc/DeploymentMod/.direnv/python-3.12/lib/python3.12/site-packages/rocketpy/mathutils/function.py:313, in Function.__update_interpolation_coefficients(self, method)
#     311     self._coeffs = self.__akima_coefficients__
#     312 elif method == "spline" or method is None:
# --> 313     self.__interpolate_spline__()
#     314     self._coeffs = self.__spline_coefficients__
#     315 else:
#
# File ~/Clubs/Launch/Misc/DeploymentMod/.direnv/python-3.12/lib/python3.12/site-packages/rocketpy/mathutils/function.py:1598, in Function.__interpolate_spline__(self)
#    1596 vector_b.append(0)
#    1597 # Solve the system for c coefficients
# -> 1598 c = linalg.solve_banded(
#    1599     (1, 1), banded_matrix, vector_b, overwrite_ab=True, overwrite_b=True
#    1600 )
#    1601 # Calculate other coefficients
#    1602 b = (y[1:] - y[:-1]) / h - h * (2 * c[:-1] + c[1:]) / 3
#
# File ~/Clubs/Launch/Misc/DeploymentMod/.direnv/python-3.12/lib/python3.12/site-packages/scipy/linalg/_basic.py:441, in solve_banded(l_and_u, ab, b, overwrite_ab, overwrite_b, check_finite)
#     372 """
#     373 Solve the equation a x = b for x, assuming a is banded matrix.
#     374
#    (...)
#     437
#     438 """
#     440 a1 = _asarray_validated(ab, check_finite=check_finite, as_inexact=True)
# --> 441 b1 = _asarray_validated(b, check_finite=check_finite, as_inexact=True)
#     443 # Validate shapes.
#     444 if a1.shape[-1] != b1.shape[0]:
#
# File ~/Clubs/Launch/Misc/DeploymentMod/.direnv/python-3.12/lib/python3.12/site-packages/scipy/_lib/_util.py:321, in _asarray_validated(a, check_finite, sparse_ok, objects_ok, mask_ok, as_inexact)
#     319         raise ValueError('masked arrays are not supported')
#     320 toarray = np.asarray_chkfinite if check_finite else np.asarray
# --> 321 a = toarray(a)
#     322 if not objects_ok:
#     323     if a.dtype is np.dtype('O'):
#
# File ~/Clubs/Launch/Misc/DeploymentMod/.direnv/python-3.12/lib/python3.12/site-packages/numpy/lib/_function_base_impl.py:649, in asarray_chkfinite(a, dtype, order)
#     647 a = asarray(a, dtype=dtype, order=order)
#     648 if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
# --> 649     raise ValueError(
#     650         "array must not contain infs or NaNs")
#     651 return a
#
# ValueError: array must not contain infs or NaNs

# %%
motor.all_info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 motor.all_info()
#
# NameError: name 'motor' is not defined

# %% [markdown]
# ## Rocket
# Currently, only single stage rockets are supported by Rocket-Serializer
# We will start by defining the aerodynamic surfaces, and then build the rocket.

# %% [markdown]
# ### Nosecones

# %%
nosecone = NoseCone(
    length=0.5587999999999996,
    kind='ogive',
    base_radius=0.07874,
    rocket_radius=0.07874,
    name='0.5587999999999996',
)

# %% [markdown]
# ### Fins
# As rocketpy allows for multiple fins sets, we will create a dictionary with all the fins sets and then add them to the rocket

# %%
trapezoidal_fins = {}

# %%
trapezoidal_fins[0] = TrapezoidalFins(
    n=4,
    root_chord=0.30479999999999996,
    tip_chord=0.127,
    span=0.15494,
    cant_angle=0.0,
    sweep_length= 0.20976060467980678,
    sweep_angle= None,
    rocket_radius=0.07874,
    name='Trapezoidal Fins',
)

# %% [markdown]
# ### Transitions (Tails)
# As rocketpy allows for multiple tails, we will create a dictionary with all the tails and then add them to the rocket

# %%
tails = {}

# %%
tails[0] = Tail(
    top_radius=0.07874,
    bottom_radius=0.060325,
    length=0.15239999999999998,
    rocket_radius=0.07874,
    name='Boat Tail',
)

# %% [markdown]
# ### Parachutes
# As rocketpy allows for multiple parachutes, we will create a dictionary with all the parachutes and then add them to the rocket

# %%
parachutes = {}

# %%
parachutes[0] = Parachute(
    name='Main Parachute & 2 TD-2s',
    cd_s=10.192,
    trigger=304.800,
    sampling_rate=100, 
)

# %%
rocket = Rocket(
    radius=0.07874,
    mass=23.915,
    inertia=[0.113, 0.113, 13.739],
    power_off_drag='drag_curve.csv',
    power_on_drag='drag_curve.csv',
    center_of_mass_without_motor=1.692,
    coordinate_system_orientation='nose_to_tail',
)

# %% [markdown]
# ### Adding surfaces to the rocket
# Now that we have all the surfaces, we can add them to the rocket

# %%
rocket.add_surfaces(surfaces=[nosecone, trapezoidal_fins[0], tails[0]], positions=[0.0, 2.7559, 2.7558999999999996])

# %%
rocket.add_motor(motor, position= 2.5599352533109103)

# %% [markdown]
# Adding parachutes to the rocket

# %%
rocket.parachutes = list(parachutes.values())

# %% [markdown]
# ### Rail Buttons

# %%
rail_buttons = rocket.set_rail_buttons(
   upper_button_position=2.476,
   lower_button_position=4.299,
   angular_position=180.000,
)

# %%
### Rocket Info
rocket.all_info()

# %% [markdown]
# ## Flight
# We will now create the flight simulation. Let's go!

# %%
flight = Flight(
    rocket=rocket,
    environment=env,
    rail_length=3.683,
    inclination=85.0,
    heading=90.0,
    terminate_on_apogee=False,
    max_time=600,
)

# %%
flight.all_info()

# %% [markdown]
# ## Compare Results
# We will now compare the results of the simulation with the parameters used to create it. Let's go!

# %%
### OpenRocket vs RocketPy Parameters
time_to_apogee_ork = 26.34
time_to_apogee_rpy = flight.apogee_time
print(f"Time to apogee (OpenRocket): {time_to_apogee_ork:.3f} s")
print(f"Time to apogee (RocketPy):   {time_to_apogee_rpy:.3f} s")
apogee_difference = time_to_apogee_rpy - time_to_apogee_ork
error = abs((apogee_difference)/time_to_apogee_rpy)*100
print(f"Time to apogee difference:   {error:.3f} %")
print()

flight_time_ork = 228.445
flight_time_rpy = flight.t_final
print(f"Flight time (OpenRocket): {flight_time_ork:.3f} s")
print(f"Flight time (RocketPy):   {flight_time_rpy:.3f} s")
flight_time_difference = flight_time_rpy - flight_time_ork
error_flight_time = abs((flight_time_difference)/flight_time_rpy)*100
print(f"Flight time difference:   {error_flight_time:.3f} %")
print()

ground_hit_velocity_ork = -6.251
ground_hit_velocity_rpy = flight.impact_velocity
print(f"Ground hit velocity (OpenRocket): {ground_hit_velocity_ork:.3f} m/s")
print(f"Ground hit velocity (RocketPy):   {ground_hit_velocity_rpy:.3f} m/s")
ground_hit_velocity_difference = ground_hit_velocity_rpy - ground_hit_velocity_ork
error_ground_hit_velocity = abs((ground_hit_velocity_difference)/ground_hit_velocity_rpy)*100
print(f"Ground hit velocity difference:   {error_ground_hit_velocity:.3f} %")
print()

launch_rod_velocity_ork = 29.236
launch_rod_velocity_rpy = flight.out_of_rail_velocity
print(f"Launch rod velocity (OpenRocket): {launch_rod_velocity_ork:.3f} m/s")
print(f"Launch rod velocity (RocketPy):   {launch_rod_velocity_rpy:.3f} m/s")
launch_rod_velocity_difference = launch_rod_velocity_rpy - launch_rod_velocity_ork
error_launch_rod_velocity = abs((launch_rod_velocity_difference)/launch_rod_velocity_rpy)*100
print(f"Launch rod velocity difference:   {error_launch_rod_velocity:.3f} %")
print()

max_acceleration_ork = 133.101
max_acceleration_rpy = flight.max_acceleration
print(f"Max acceleration (OpenRocket): {max_acceleration_ork:.3f} m/s²")
print(f"Max acceleration (RocketPy):   {max_acceleration_rpy:.3f} m/s²")
max_acceleration_difference = max_acceleration_rpy - max_acceleration_ork
error_max_acceleration = abs((max_acceleration_difference)/max_acceleration_rpy)*100
print(f"Max acceleration difference:   {error_max_acceleration:.3f} %")
print()

max_altitude_ork = 3621.121
max_altitude_rpy = flight.apogee - flight.env.elevation
print(f"Max altitude (OpenRocket): {max_altitude_ork:.3f} m")
print(f"Max altitude (RocketPy):   {max_altitude_rpy:.3f} m")
max_altitude_difference = max_altitude_rpy - max_altitude_ork
error_max_altitude = abs((max_altitude_difference)/max_altitude_rpy)*100
print(f"Max altitude difference:   {error_max_altitude:.3f} %")
print()

max_mach_ork = 0.996
max_mach_rpy = flight.max_mach_number 
print(f"Max Mach (OpenRocket): {max_mach_ork:.3f}")
print(f"Max Mach (RocketPy):   {max_mach_rpy:.3f}")
max_mach_difference = max_mach_rpy - max_mach_ork
error_max_mach = abs((max_mach_difference)/max_mach_rpy)*100
print(f"Max Mach difference:   {error_max_mach:.3f} %")
print()

max_velocity_ork = 330.809
max_velocity_rpy = flight.max_speed
print(f"Max velocity (OpenRocket): {max_velocity_ork:.3f} m/s")
print(f"Max velocity (RocketPy):   {max_velocity_rpy:.3f} m/s")
max_velocity_difference = max_velocity_rpy - max_velocity_ork
error_max_velocity = abs((max_velocity_difference)/max_velocity_rpy)*100
print(f"Max velocity difference:   {error_max_velocity:.3f} %")
print()

max_thrust_ork = 3895.789
max_thrust_rpy = flight.rocket.motor.thrust.max
print(f"Max thrust (OpenRocket): {max_thrust_ork:.3f} N")
print(f"Max thrust (RocketPy):   {max_thrust_rpy:.3f} N")
max_thrust_difference = max_thrust_rpy - max_thrust_ork
error_max_thrust = abs((max_thrust_difference)/max_thrust_rpy)*100
print(f"Max thrust difference:   {error_max_thrust:.3f} %")
print()

burnout_stability_margin_ork = 1.647
burnout_stability_margin_rpy = flight.stability_margin(flight.rocket.motor.burn_out_time)
print(f"Burnout stability margin (OpenRocket): {burnout_stability_margin_ork:.3f}")
print(f"Burnout stability margin (RocketPy):   {burnout_stability_margin_rpy:.3f}")
burnout_stability_margin_difference = burnout_stability_margin_rpy - burnout_stability_margin_ork
error_burnout_stability_margin = abs((burnout_stability_margin_difference)/burnout_stability_margin_rpy)*100
print(f"Burnout stability margin difference:   {error_burnout_stability_margin:.3f} %")
print()

max_stability_margin_ork = 3.18
max_stability_margin_rpy = flight.max_stability_margin
print(f"Max stability margin (OpenRocket): {max_stability_margin_ork:.3f}")
print(f"Max stability margin (RocketPy):   {max_stability_margin_rpy:.3f}")
max_stability_margin_difference = max_stability_margin_rpy - max_stability_margin_ork
error_max_stability_margin = abs((max_stability_margin_difference)/max_stability_margin_rpy)*100
print(f"Max stability margin difference:   {error_max_stability_margin:.3f} %")
print()

min_stability_margin_ork = 0.088
min_stability_margin_rpy = flight.min_stability_margin
print(f"Min stability margin (OpenRocket): {min_stability_margin_ork:.3f}")
print(f"Min stability margin (RocketPy):   {min_stability_margin_rpy:.3f}")
min_stability_margin_difference = min_stability_margin_rpy - min_stability_margin_ork
error_min_stability_margin = abs((min_stability_margin_difference)/min_stability_margin_rpy)*100
print(f"Min stability margin difference:   {error_min_stability_margin:.3f} %")
print()
