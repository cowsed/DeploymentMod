# %%
# https://docs.rocketpy.org/en/latest/index.html

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %pip install rocketpy
# Out:
# Collecting rocketpy
#   Downloading rocketpy-1.4.1-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: numpy>=1.13 in /home/unknown/Clubs/Launch/Misc/DeploymentMod/.direnv/python-3.12/lib/python3.12/site-packages (from rocketpy) (2.0.1)
# Requirement already satisfied: scipy>=1.0 in /home/unknown/Clubs/Launch/Misc/DeploymentMod/.direnv/python-3.12/lib/python3.12/site-packages (from rocketpy) (1.14.0)
# Requirement already satisfied: matplotlib>=3.0 in /home/unknown/Clubs/Launch/Misc/DeploymentMod/.direnv/python-3.12/lib/python3.12/site-packages (from rocketpy) (3.9.1)
# Collecting netCDF4>=1.6.4 (from rocketpy)
#   Downloading netCDF4-1.7.1.post1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting requests (from rocketpy)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: pytz in /home/unknown/Clubs/Launch/Misc/DeploymentMod/.direnv/python-3.12/lib/python3.12/site-packages (from rocketpy) (2024.1)
# Collecting simplekml (from rocketpy)
#   Downloading simplekml-1.3.6.tar.gz (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 2.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: contourpy>=1.0.1 in /home/unknown/Clubs/Launch/Misc/DeploymentMod/.direnv/python-3.12/lib/python3.12/site-packages (from matplotlib>=3.0->rocketpy) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/unknown/Clubs/Launch/Misc/DeploymentMod/.direnv/python-3.12/lib/python3.12/site-packages (from matplotlib>=3.0->rocketpy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/unknown/Clubs/Launch/Misc/DeploymentMod/.direnv/python-3.12/lib/python3.12/site-packages (from matplotlib>=3.0->rocketpy) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/unknown/Clubs/Launch/Misc/DeploymentMod/.direnv/python-3.12/lib/python3.12/site-packages (from matplotlib>=3.0->rocketpy) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/unknown/Clubs/Launch/Misc/DeploymentMod/.direnv/python-3.12/lib/python3.12/site-packages (from matplotlib>=3.0->rocketpy) (24.1)
# Requirement already satisfied: pillow>=8 in /home/unknown/Clubs/Launch/Misc/DeploymentMod/.direnv/python-3.12/lib/python3.12/site-packages (from matplotlib>=3.0->rocketpy) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/unknown/Clubs/Launch/Misc/DeploymentMod/.direnv/python-3.12/lib/python3.12/site-packages (from matplotlib>=3.0->rocketpy) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/unknown/Clubs/Launch/Misc/DeploymentMod/.direnv/python-3.12/lib/python3.12/site-packages (from matplotlib>=3.0->rocketpy) (2.9.0.post0)
# Collecting cftime (from netCDF4>=1.6.4->rocketpy)
#   Downloading cftime-1.6.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.7 kB)
# Collecting certifi (from netCDF4>=1.6.4->rocketpy)
#   Downloading certifi-2024.7.4-py3-none-any.whl.metadata (2.2 kB)
# Collecting charset-normalizer<4,>=2 (from requests->rocketpy)
#   Using cached charset_normalizer-3.3.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (33 kB)
# Collecting idna<4,>=2.5 (from requests->rocketpy)
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->rocketpy)
#   Using cached urllib3-2.2.2-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: six>=1.5 in /home/unknown/Clubs/Launch/Misc/DeploymentMod/.direnv/python-3.12/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.0->rocketpy) (1.16.0)
# Downloading rocketpy-1.4.1-py3-none-any.whl (296 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.0/296.0 kB 10.4 MB/s eta 0:00:00
# Downloading netCDF4-1.7.1.post1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 34.0 MB/s eta 0:00:0000:0100:01
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading certifi-2024.7.4-py3-none-any.whl (162 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.0/163.0 kB 44.5 MB/s eta 0:00:00
# Using cached charset_normalizer-3.3.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (141 kB)
# Using cached idna-3.7-py3-none-any.whl (66 kB)
# Using cached urllib3-2.2.2-py3-none-any.whl (121 kB)
# Downloading cftime-1.6.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 34.1 MB/s eta 0:00:00a 0:00:01
# Building wheels for collected packages: simplekml
#   Building wheel for simplekml (pyproject.toml) ... done
#   Created wheel for simplekml: filename=simplekml-1.3.6-py3-none-any.whl size=65860 sha256=4559703b9d4fb5e1279b3335c1b7cec9c1bbc05bef35ef532911ffbed271650c
#   Stored in directory: /home/unknown/.cache/pip/wheels/83/ee/f2/65cecfd948f1429ead035fd6d56bc6bd6574a636ddc4d65cbd
# Successfully built simplekml
# Installing collected packages: simplekml, urllib3, idna, charset-normalizer, cftime, certifi, requests, netCDF4, rocketpy
# Successfully installed certifi-2024.7.4 cftime-1.6.4 charset-normalizer-3.3.2 idna-3.7 netCDF4-1.7.1.post1 requests-2.32.3 rocketpy-1.4.1 simplekml-1.3.6 urllib3-2.2.2
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from rocketpy import Environment, SolidMotor, Rocket, Flight

# %%
env = Environment(latitude=32.990254, longitude=-106.974998, elevation=1400)
# Out:
# /home/unknown/Clubs/Launch/Misc/DeploymentMod/.direnv/python-3.12/lib/python3.12/site-packages/rocketpy/mathutils/function.py:3125: UserWarning: Extrapolation method set to 'constant' because the linear method is not supported.
#   warnings.warn(

# %%
import datetime

tomorrow = datetime.date.today() + datetime.timedelta(days=1)

env.set_date(
    (tomorrow.year, tomorrow.month, tomorrow.day, 12)
)  # Hour given in UTC time

# %%
env.set_atmospheric_model(type="Forecast", file="GFS")

# %%
env.max_expected_height = 5000  # adjust the plots to this height
env.info()
# Out:
# Gravity Details
#
# Acceleration of gravity at surface level:    9.7911 m/s²
# Acceleration of gravity at   5.000 km (ASL): 9.7802 m/s²
#
#
# Launch Site Details
#
# Launch Date: 2024-08-02 12:00:00 UTC
# Launch Site Latitude: 32.99025°
# Launch Site Longitude: -106.97500°
# Reference Datum: SIRGAS2000
# Launch Site UTM coordinates: 315468.64 W    3651938.65 N
# Launch Site UTM zone: 13S
# Launch Site Surface Elevation: 1471.5 m
#
#
# Atmospheric Model Details
#
# Atmospheric Model Type: Forecast
# Forecast Maximum Height: 5.000 km
# Forecast Time Period: from 2024-08-01 18:00:00 to 2024-08-17 18:00:00 utc
# Forecast Hour Interval: 3 hrs
# Forecast Latitude Range: From -90.0° to 90.0°
# Forecast Longitude Range: From 0.0° to 359.75°
#
# Surface Atmospheric Conditions
#
# Surface Wind Speed: 64.47 m/s
# Surface Wind Direction: 179.69°
# Surface Wind Heading: 3.73°
# Surface Pressure: 859.00 hPa
# Surface Temperature: 298.05 K
# Surface Air Density: 1.004 kg/m³
# Surface Speed of Sound: 346.09 m/s
#
#
# Earth Model Details
#
# Earth Radius at Launch site: 6371.83 km
# Semi-major Axis: 6378.14 km
# Semi-minor Axis: 6356.75 km
# Flattening: 0.0034
#
#
# Atmospheric Model Plots

# %%
Pro75M1670 = SolidMotor(
    thrust_source="Data/Rocketpy/Motors/Cesaroni_M1670.eng",
    dry_mass=1.815,
    dry_inertia=(0.125, 0.125, 0.002),
    nozzle_radius=33 / 1000,
    grain_number=5,
    grain_density=1815,
    grain_outer_radius=33 / 1000,
    grain_initial_inner_radius=15 / 1000,
    grain_initial_height=120 / 1000,
    grain_separation=5 / 1000,
    grains_center_of_mass_position=0.397,
    center_of_dry_mass_position=0.317,
    nozzle_position=0,
    burn_time=3.9,
    throat_radius=11 / 1000,
    coordinate_system_orientation="nozzle_to_combustion_chamber",
)

# %%
Pro75M1670.info()
# Out:
# Nozzle Details
# Nozzle Radius: 0.033 m
# Nozzle Throat Radius: 0.011 m
#
# Grain Details
# Number of Grains: 5
# Grain Spacing: 0.005 m
# Grain Density: 1815 kg/m3
# Grain Outer Radius: 0.033 m
# Grain Inner Radius: 0.015 m
# Grain Height: 0.12 m
# Grain Volume: 0.000 m3
# Grain Mass: 0.591 kg
#
# Motor Details
# Total Burning Time: 3.9 s
# Total Propellant Mass: 2.956 kg
# Average Propellant Exhaust Velocity: 2038.745 m/s
# Average Thrust: 1545.218 N
# Maximum Thrust: 2200.0 N at 0.15 s after ignition.
# Total Impulse: 6026.350 Ns

# %%
calisto = Rocket(
    radius=127 / 2000,
    mass=14.426,
    inertia=(6.321, 6.321, 0.034),
    power_off_drag="../../data/calisto/powerOffDragCurve.csv",
    power_on_drag="../../data/calisto/powerOnDragCurve.csv",
    center_of_mass_without_motor=0,
    coordinate_system_orientation="tail_to_nose",
)

rail_buttons = calisto.set_rail_buttons(
    upper_button_position=0.0818,
    lower_button_position=-0.618,
    angular_position=45,
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/Clubs/Launch/Misc/DeploymentMod/.direnv/python-3.12/lib/python3.12/site-packages/rocketpy/mathutils/function.py:2986, in Function.__validate_source(self, source)
#    2985 try:
# -> 2986     source = np.loadtxt(source, delimiter=",", dtype=np.float64)
#    2987 except ValueError:
#
# File ~/Clubs/Launch/Misc/DeploymentMod/.direnv/python-3.12/lib/python3.12/site-packages/numpy/lib/_npyio_impl.py:1381, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, quotechar, like)
#    1379     delimiter = delimiter.decode('latin1')
# -> 1381 arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#    1382             converters=converters, skiplines=skiprows, usecols=usecols,
#    1383             unpack=unpack, ndmin=ndmin, encoding=encoding,
#    1384             max_rows=max_rows, quote=quotechar)
#    1386 return arr
#
# File ~/Clubs/Launch/Misc/DeploymentMod/.direnv/python-3.12/lib/python3.12/site-packages/numpy/lib/_npyio_impl.py:997, in _read(fname, delimiter, comment, quote, imaginary_unit, usecols, skiplines, max_rows, converters, ndmin, unpack, dtype, encoding)
#     996 if isinstance(fname, str):
# --> 997     fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     998     if encoding is None:
#
# File ~/Clubs/Launch/Misc/DeploymentMod/.direnv/python-3.12/lib/python3.12/site-packages/numpy/lib/_datasource.py:192, in open(path, mode, destpath, encoding, newline)
#     191 ds = DataSource(destpath)
# --> 192 return ds.open(path, mode, encoding=encoding, newline=newline)
#
# File ~/Clubs/Launch/Misc/DeploymentMod/.direnv/python-3.12/lib/python3.12/site-packages/numpy/lib/_datasource.py:532, in DataSource.open(self, path, mode, encoding, newline)
#     531 else:
# --> 532     raise FileNotFoundError(f"{path} not found.")
#
# FileNotFoundError: ../../data/calisto/powerOffDragCurve.csv not found.
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 calisto = Rocket(
#       2     radius=127 / 2000,
#       3     mass=14.426,
#       4     inertia=(6.321, 6.321, 0.034),
#       5     power_off_drag="../../data/calisto/powerOffDragCurve.csv",
#       6     power_on_drag="../../data/calisto/powerOnDragCurve.csv",
#       7     center_of_mass_without_motor=0,
#       8     coordinate_system_orientation="tail_to_nose",
#       9 )
#      11 rail_buttons = calisto.set_rail_buttons(
#      12     upper_button_position=0.0818,
#      13     lower_button_position=-0.618,
#      14     angular_position=45,
#      15 )
#
# File ~/Clubs/Launch/Misc/DeploymentMod/.direnv/python-3.12/lib/python3.12/site-packages/rocketpy/rocket/rocket.py:331, in Rocket.__init__(self, radius, mass, inertia, power_off_drag, power_on_drag, center_of_mass_without_motor, coordinate_system_orientation)
#     324 self.stability_margin = Function(
#     325     lambda mach, time: 0,
#     326     inputs=["Mach", "Time (s)"],
#     327     outputs="Stability Margin (c)",
#     328 )
#     330 # Define aerodynamic drag coefficients
# --> 331 self.power_off_drag = Function(
#     332     power_off_drag,
#     333     "Mach Number",
#     334     "Drag Coefficient with Power Off",
#     335     "linear",
#     336     "constant",
#     337 )
#     338 self.power_on_drag = Function(
#     339     power_on_drag,
#     340     "Mach Number",
#    (...)
#     343     "constant",
#     344 )
#     346 # Create a, possibly, temporary empty motor
#     347 # self.motors = Components()  # currently unused, only 1 motor is supported
#
# File ~/Clubs/Launch/Misc/DeploymentMod/.direnv/python-3.12/lib/python3.12/site-packages/rocketpy/mathutils/function.py:136, in Function.__init__(self, source, inputs, outputs, interpolation, extrapolation, title)
#     133 self.__img_dim__ = 1  # always 1, here for backwards compatibility
#     135 # args must be passed from self.
# --> 136 self.set_source(self.source)
#     137 self.set_inputs(self.__inputs__)
#     138 self.set_outputs(self.__outputs__)
#
# File ~/Clubs/Launch/Misc/DeploymentMod/.direnv/python-3.12/lib/python3.12/site-packages/rocketpy/mathutils/function.py:218, in Function.set_source(self, source)
#     172 def set_source(self, source):  # pylint: disable=too-many-statements
#     173     """Sets the data source for the function, defining how the function
#     174     produces output from a given input.
#     175
#    (...)
#     216         Returns the Function instance.
#     217     """
# --> 218     source = self.__validate_source(source)
#     220     # Handle callable source or number source
#     221     if callable(source):
#
# File ~/Clubs/Launch/Misc/DeploymentMod/.direnv/python-3.12/lib/python3.12/site-packages/rocketpy/mathutils/function.py:3000, in Function.__validate_source(self, source)
#    2998                 self.__outputs__ = [header[-1]]
#    2999     except Exception as e:
# -> 3000         raise ValueError(
#    3001             "Could not read the csv or txt file to create Function source."
#    3002         ) from e
#    3004 if isinstance(source, (list, np.ndarray)):
#    3005     # Triggers an error if source is not a list of numbers
#    3006     source = np.array(source, dtype=np.float64)
#
# ValueError: Could not read the csv or txt file to create Function source.
